# %%
import numpy as np
import json
import platform
import math
import matplotlib.pyplot as plt

# %%
def read_data():
    read_file = "global_router_plt.json"
    data = json.load(open(read_file,'r'))
    global_route = data["Glbaol_Routes"]
    Gcell = data["Gcell"]
    blocks = data["Blocks"]
    node_box = data["Cell box"]
    return global_route,Gcell,blocks,node_box

def plot_global_routing(global_routr,Gcell,blocks,node_box,name):
    
    plt.figure()
    
    #plot_box(node_box['LLx'], node_box['LLy'],node_box['URx'],node_box['URy'],'k')
    
    #for tile in Gcell:
        #plot_dot(tile['x'],tile['y'],'k')
    
    for net in global_routr:
    
        if net['name']!=name:
            continue
    
        for path in net['global_path']:
            plot_line(path['llx'],path['lly'],path['urx'],path['ury'],'k')
        
        for terminal in net['terminals']:
            plot_dot(terminal['x'],terminal['y'],'r')
            
        for stiner_node in net['steiner_node']:
            plot_dot(stiner_node['x'],stiner_node['y'],'g')
            
    for block in blocks:
        
        plot_box(block['Box']['LLx'], block['Box']['LLy'],block['Box']['URx'],block['Box']['URy'],'k')
            
    
    plt.show()
    
def plot_box(llx,lly,urx,ury,c):
    plt.plot([llx,urx], [lly,lly], lw=2, color=c)
    plt.plot([urx,urx], [lly,ury], lw=2, color=c)
    plt.plot([urx,llx], [ury,ury], lw=2, color=c)
    plt.plot([llx,llx], [lly,ury], lw=2, color=c)
    
def plot_line(llx,lly,urx,ury,c):
    plt.plot([llx,urx], [lly,ury], lw=2, color=c)
    
def plot_dot(x,y,c):
    plt.plot(x,y, 'o', color=c)

# %%
global_routr,Gcell,blocks,node_box=read_data()

# %%
plot_global_routing(global_routr,Gcell,blocks,node_box,global_routr[0]['name'])
print(global_routr[0])
# Out:
# {'global_path': [{'Physical Layer ll': 2, 'Physical Layer ur': 3, 'llx': 4860, 'lly': 540, 'urx': 4860, 'ury': 540}, {'Physical Layer ll': 3, 'Physical Layer ur': 4, 'llx': 4860, 'lly': 540, 'urx': 4860, 'ury': 540}, {'Physical Layer ll': 4, 'Physical Layer ur': 5, 'llx': 4860, 'lly': 540, 'urx': 4860, 'ury': 540}, {'Physical Layer ll': 5, 'Physical Layer ur': 5, 'llx': 4860, 'lly': 540, 'urx': 5940, 'ury': 540}, {'Physical Layer ll': 5, 'Physical Layer ur': 5, 'llx': 5940, 'lly': 540, 'urx': 7020, 'ury': 540}, {'Physical Layer ll': 5, 'Physical Layer ur': 4, 'llx': 7020, 'lly': 540, 'urx': 7020, 'ury': 540}, {'Physical Layer ll': 4, 'Physical Layer ur': 4, 'llx': 7020, 'lly': 540, 'urx': 7020, 'ury': 1620}, {'Physical Layer ll': 4, 'Physical Layer ur': 3, 'llx': 7020, 'lly': 1620, 'urx': 7020, 'ury': 1620}, {'Physical Layer ll': 3, 'Physical Layer ur': 2, 'llx': 7020, 'lly': 1620, 'urx': 7020, 'ury': 1620}], 'name': 'vout', 'steiner_node': [], 'terminals': [{'Physical Layer': 2, 'x'
# ...

# %%
plot_global_routing(global_routr,Gcell,blocks,node_box,global_routr[1]['name'])
print(global_routr[1])
# Out:
# {'global_path': [{'Physical Layer ll': 2, 'Physical Layer ur': 1, 'llx': 4860, 'lly': 540, 'urx': 4860, 'ury': 540}, {'Physical Layer ll': 1, 'Physical Layer ur': 0, 'llx': 4860, 'lly': 540, 'urx': 4860, 'ury': 540}, {'Physical Layer ll': 0, 'Physical Layer ur': 0, 'llx': 4860, 'lly': 540, 'urx': 4860, 'ury': 1620}, {'Physical Layer ll': 0, 'Physical Layer ur': 1, 'llx': 4860, 'lly': 1620, 'urx': 4860, 'ury': 1620}, {'Physical Layer ll': 1, 'Physical Layer ur': 1, 'llx': 4860, 'lly': 1620, 'urx': 3780, 'ury': 1620}, {'Physical Layer ll': 1, 'Physical Layer ur': 1, 'llx': 3780, 'lly': 1620, 'urx': 2700, 'ury': 1620}, {'Physical Layer ll': 1, 'Physical Layer ur': 2, 'llx': 2700, 'lly': 1620, 'urx': 2700, 'ury': 1620}, {'Physical Layer ll': 2, 'Physical Layer ur': 3, 'llx': 2700, 'lly': 1620, 'urx': 2700, 'ury': 1620}, {'Physical Layer ll': 3, 'Physical Layer ur': 4, 'llx': 2700, 'lly': 1620, 'urx': 2700, 'ury': 1620}, {'Physical Layer ll': 4, 'Physical Layer ur': 4, 'llx': 2700, 'lly':
# ...

# %%
plot_global_routing(global_routr,Gcell,blocks,node_box,global_routr[2]['name'])
print(global_routr[2])
# Out:
# {'global_path': [{'Physical Layer ll': 2, 'Physical Layer ur': 3, 'llx': 4860, 'lly': 540, 'urx': 4860, 'ury': 540}, {'Physical Layer ll': 3, 'Physical Layer ur': 4, 'llx': 4860, 'lly': 540, 'urx': 4860, 'ury': 540}, {'Physical Layer ll': 4, 'Physical Layer ur': 5, 'llx': 4860, 'lly': 540, 'urx': 4860, 'ury': 540}, {'Physical Layer ll': 5, 'Physical Layer ur': 6, 'llx': 4860, 'lly': 540, 'urx': 4860, 'ury': 540}, {'Physical Layer ll': 6, 'Physical Layer ur': 7, 'llx': 4860, 'lly': 540, 'urx': 4860, 'ury': 540}, {'Physical Layer ll': 7, 'Physical Layer ur': 8, 'llx': 4860, 'lly': 540, 'urx': 4860, 'ury': 540}, {'Physical Layer ll': 8, 'Physical Layer ur': 8, 'llx': 4860, 'lly': 540, 'urx': 4860, 'ury': 1620}, {'Physical Layer ll': 8, 'Physical Layer ur': 7, 'llx': 4860, 'lly': 1620, 'urx': 4860, 'ury': 1620}, {'Physical Layer ll': 7, 'Physical Layer ur': 6, 'llx': 4860, 'lly': 1620, 'urx': 4860, 'ury': 1620}, {'Physical Layer ll': 6, 'Physical Layer ur': 5, 'llx': 4860, 'lly': 1620, '
# ...

# %%
plot_global_routing(global_routr,Gcell,blocks,node_box,global_routr[3]['name'])
print(global_routr[3])
# Out:
# {'global_path': [{'Physical Layer ll': 2, 'Physical Layer ur': 3, 'llx': 2700, 'lly': 3780, 'urx': 2700, 'ury': 3780}, {'Physical Layer ll': 3, 'Physical Layer ur': 4, 'llx': 2700, 'lly': 3780, 'urx': 2700, 'ury': 3780}, {'Physical Layer ll': 4, 'Physical Layer ur': 5, 'llx': 2700, 'lly': 3780, 'urx': 2700, 'ury': 3780}, {'Physical Layer ll': 5, 'Physical Layer ur': 6, 'llx': 2700, 'lly': 3780, 'urx': 2700, 'ury': 3780}, {'Physical Layer ll': 6, 'Physical Layer ur': 6, 'llx': 2700, 'lly': 3780, 'urx': 2700, 'ury': 2700}, {'Physical Layer ll': 6, 'Physical Layer ur': 6, 'llx': 2700, 'lly': 2700, 'urx': 2700, 'ury': 1620}, {'Physical Layer ll': 6, 'Physical Layer ur': 6, 'llx': 2700, 'lly': 1620, 'urx': 2700, 'ury': 540}, {'Physical Layer ll': 6, 'Physical Layer ur': 5, 'llx': 2700, 'lly': 540, 'urx': 2700, 'ury': 540}, {'Physical Layer ll': 5, 'Physical Layer ur': 5, 'llx': 2700, 'lly': 540, 'urx': 1620, 'ury': 540}, {'Physical Layer ll': 5, 'Physical Layer ur': 4, 'llx': 1620, 'lly':
# ...

# %%
plot_global_routing(global_routr,Gcell,blocks,node_box,global_routr[4]['name'])
print(global_routr[4])
# Out:
# {'global_path': [{'Physical Layer ll': 2, 'Physical Layer ur': 3, 'llx': 8100, 'lly': 540, 'urx': 8100, 'ury': 540}, {'Physical Layer ll': 3, 'Physical Layer ur': 4, 'llx': 8100, 'lly': 540, 'urx': 8100, 'ury': 540}, {'Physical Layer ll': 4, 'Physical Layer ur': 5, 'llx': 8100, 'lly': 540, 'urx': 8100, 'ury': 540}, {'Physical Layer ll': 5, 'Physical Layer ur': 6, 'llx': 8100, 'lly': 540, 'urx': 8100, 'ury': 540}, {'Physical Layer ll': 6, 'Physical Layer ur': 7, 'llx': 8100, 'lly': 540, 'urx': 8100, 'ury': 540}, {'Physical Layer ll': 7, 'Physical Layer ur': 7, 'llx': 8100, 'lly': 540, 'urx': 7020, 'ury': 540}, {'Physical Layer ll': 7, 'Physical Layer ur': 7, 'llx': 7020, 'lly': 540, 'urx': 5940, 'ury': 540}, {'Physical Layer ll': 7, 'Physical Layer ur': 6, 'llx': 5940, 'lly': 540, 'urx': 5940, 'ury': 540}, {'Physical Layer ll': 6, 'Physical Layer ur': 6, 'llx': 5940, 'lly': 540, 'urx': 5940, 'ury': 1620}, {'Physical Layer ll': 6, 'Physical Layer ur': 6, 'llx': 5940, 'lly': 1620, 'urx'
# ...

# %%
plot_global_routing(global_routr,Gcell,blocks,node_box,global_routr[5]['name'])
print(global_routr[5])
# Out:
# {'global_path': [{'Physical Layer ll': 2, 'Physical Layer ur': 2, 'llx': 8100, 'lly': 540, 'urx': 8100, 'ury': 540}], 'name': 'vinp', 'steiner_node': [], 'terminals': [{'Physical Layer': 2, 'x': 8100, 'y': 540}]}

# %%
plot_global_routing(global_routr,Gcell,blocks,node_box,global_routr[6]['name'])
print(global_routr[6])
# Out:
# {'global_path': [{'Physical Layer ll': 2, 'Physical Layer ur': 3, 'llx': 8100, 'lly': 540, 'urx': 8100, 'ury': 540}, {'Physical Layer ll': 3, 'Physical Layer ur': 3, 'llx': 8100, 'lly': 540, 'urx': 7020, 'ury': 540}, {'Physical Layer ll': 3, 'Physical Layer ur': 3, 'llx': 7020, 'lly': 540, 'urx': 5940, 'ury': 540}, {'Physical Layer ll': 3, 'Physical Layer ur': 3, 'llx': 5940, 'lly': 540, 'urx': 4860, 'ury': 540}, {'Physical Layer ll': 3, 'Physical Layer ur': 3, 'llx': 4860, 'lly': 540, 'urx': 3780, 'ury': 540}, {'Physical Layer ll': 3, 'Physical Layer ur': 3, 'llx': 3780, 'lly': 540, 'urx': 2700, 'ury': 540}, {'Physical Layer ll': 3, 'Physical Layer ur': 2, 'llx': 2700, 'lly': 540, 'urx': 2700, 'ury': 540}, {'Physical Layer ll': 2, 'Physical Layer ur': 3, 'llx': 2700, 'lly': 540, 'urx': 2700, 'ury': 540}, {'Physical Layer ll': 3, 'Physical Layer ur': 3, 'llx': 2700, 'lly': 540, 'urx': 1620, 'ury': 540}, {'Physical Layer ll': 3, 'Physical Layer ur': 3, 'llx': 1620, 'lly': 540, 'urx': 
# ...

# %%
plot_global_routing(global_routr,Gcell,blocks,node_box,global_routr[7]['name'])
print(global_routr[7])
# Out:
# {'global_path': [{'Physical Layer ll': 2, 'Physical Layer ur': 3, 'llx': 540, 'lly': 540, 'urx': 540, 'ury': 540}, {'Physical Layer ll': 3, 'Physical Layer ur': 4, 'llx': 540, 'lly': 540, 'urx': 540, 'ury': 540}, {'Physical Layer ll': 4, 'Physical Layer ur': 5, 'llx': 540, 'lly': 540, 'urx': 540, 'ury': 540}, {'Physical Layer ll': 5, 'Physical Layer ur': 6, 'llx': 540, 'lly': 540, 'urx': 540, 'ury': 540}, {'Physical Layer ll': 6, 'Physical Layer ur': 6, 'llx': 540, 'lly': 540, 'urx': 540, 'ury': 1620}, {'Physical Layer ll': 6, 'Physical Layer ur': 6, 'llx': 540, 'lly': 1620, 'urx': 540, 'ury': 2700}, {'Physical Layer ll': 6, 'Physical Layer ur': 5, 'llx': 540, 'lly': 2700, 'urx': 540, 'ury': 2700}, {'Physical Layer ll': 5, 'Physical Layer ur': 5, 'llx': 540, 'lly': 2700, 'urx': 1620, 'ury': 2700}, {'Physical Layer ll': 5, 'Physical Layer ur': 5, 'llx': 1620, 'lly': 2700, 'urx': 2700, 'ury': 2700}, {'Physical Layer ll': 5, 'Physical Layer ur': 4, 'llx': 2700, 'lly': 2700, 'urx': 2700,
# ...

# %%
plot_global_routing(global_routr,Gcell,blocks,node_box,global_routr[8]['name'])
print(global_routr[8])
# Out:
# {'global_path': [{'Physical Layer ll': 2, 'Physical Layer ur': 2, 'llx': 1620, 'lly': 540, 'urx': 1620, 'ury': 540}], 'name': 'vinn', 'steiner_node': [], 'terminals': [{'Physical Layer': 2, 'x': 1620, 'y': 540}]}

# %%
plot_global_routing(global_routr,Gcell,blocks,node_box,global_routr[9]['name'])
print(global_routr[9])
# Out:
# {'global_path': [{'Physical Layer ll': 1, 'Physical Layer ur': 2, 'llx': 6966, 'lly': 1620, 'urx': 6966, 'ury': 1620}, {'Physical Layer ll': 2, 'Physical Layer ur': 3, 'llx': 6966, 'lly': 1620, 'urx': 6966, 'ury': 1620}, {'Physical Layer ll': 3, 'Physical Layer ur': 4, 'llx': 6966, 'lly': 1620, 'urx': 6966, 'ury': 1620}, {'Physical Layer ll': 4, 'Physical Layer ur': 5, 'llx': 6966, 'lly': 1620, 'urx': 6966, 'ury': 1620}, {'Physical Layer ll': 5, 'Physical Layer ur': 6, 'llx': 6966, 'lly': 1620, 'urx': 6966, 'ury': 1620}, {'Physical Layer ll': 6, 'Physical Layer ur': 6, 'llx': 6966, 'lly': 1620, 'urx': 6966, 'ury': 2700}, {'Physical Layer ll': 6, 'Physical Layer ur': 6, 'llx': 6966, 'lly': 2700, 'urx': 6966, 'ury': 3780}, {'Physical Layer ll': 6, 'Physical Layer ur': 5, 'llx': 6966, 'lly': 3780, 'urx': 6966, 'ury': 3780}, {'Physical Layer ll': 5, 'Physical Layer ur': 4, 'llx': 6966, 'lly': 3780, 'urx': 6966, 'ury': 3780}, {'Physical Layer ll': 4, 'Physical Layer ur': 3, 'llx': 6966, '
# ...

# %%
plot_global_routing(global_routr,Gcell,blocks,node_box,global_routr[10]['name'])
print(global_routr[10])
# Out:
# {'global_path': [{'Physical Layer ll': 1, 'Physical Layer ur': 2, 'llx': 540, 'lly': 1620, 'urx': 540, 'ury': 1620}, {'Physical Layer ll': 2, 'Physical Layer ur': 3, 'llx': 540, 'lly': 1620, 'urx': 540, 'ury': 1620}, {'Physical Layer ll': 3, 'Physical Layer ur': 4, 'llx': 540, 'lly': 1620, 'urx': 540, 'ury': 1620}, {'Physical Layer ll': 4, 'Physical Layer ur': 5, 'llx': 540, 'lly': 1620, 'urx': 540, 'ury': 1620}, {'Physical Layer ll': 5, 'Physical Layer ur': 6, 'llx': 540, 'lly': 1620, 'urx': 540, 'ury': 1620}, {'Physical Layer ll': 6, 'Physical Layer ur': 6, 'llx': 540, 'lly': 1620, 'urx': 540, 'ury': 2700}, {'Physical Layer ll': 6, 'Physical Layer ur': 6, 'llx': 540, 'lly': 2700, 'urx': 540, 'ury': 3780}, {'Physical Layer ll': 6, 'Physical Layer ur': 5, 'llx': 540, 'lly': 3780, 'urx': 540, 'ury': 3780}, {'Physical Layer ll': 5, 'Physical Layer ur': 4, 'llx': 540, 'lly': 3780, 'urx': 540, 'ury': 3780}, {'Physical Layer ll': 4, 'Physical Layer ur': 3, 'llx': 540, 'lly': 3780, 'urx': 
# ...

# %%
plot_global_routing(global_routr,Gcell,blocks,node_box,global_routr[11]['name'])
print(global_routr[11])
# Out:
# {'global_path': [{'Physical Layer ll': 1, 'Physical Layer ur': 2, 'llx': 2700, 'lly': 8100, 'urx': 2700, 'ury': 8100}, {'Physical Layer ll': 2, 'Physical Layer ur': 2, 'llx': 2700, 'lly': 8100, 'urx': 2700, 'ury': 8802}, {'Physical Layer ll': 2, 'Physical Layer ur': 1, 'llx': 2700, 'lly': 8802, 'urx': 2700, 'ury': 8802}, {'Physical Layer ll': 1, 'Physical Layer ur': 1, 'llx': 2700, 'lly': 8100, 'urx': 3780, 'ury': 8100}, {'Physical Layer ll': 1, 'Physical Layer ur': 1, 'llx': 3780, 'lly': 8100, 'urx': 4860, 'ury': 8100}, {'Physical Layer ll': 1, 'Physical Layer ur': 2, 'llx': 4860, 'lly': 8100, 'urx': 4860, 'ury': 8100}, {'Physical Layer ll': 2, 'Physical Layer ur': 2, 'llx': 4860, 'lly': 8100, 'urx': 4860, 'ury': 8802}, {'Physical Layer ll': 2, 'Physical Layer ur': 1, 'llx': 4860, 'lly': 8802, 'urx': 4860, 'ury': 8802}, {'Physical Layer ll': 1, 'Physical Layer ur': 2, 'llx': 4860, 'lly': 8100, 'urx': 4860, 'ury': 8100}, {'Physical Layer ll': 2, 'Physical Layer ur': 2, 'llx': 4860, '
# ...

# %%
plot_global_routing(global_routr,Gcell,blocks,node_box,global_routr[12]['name'])
print(global_routr[12])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-66-d99652f592e9> in <module>
# ----> 1 plot_global_routing(global_routr,Gcell,blocks,node_box,global_routr[12]['name'])
#       2 print(global_routr[12])
#
# IndexError: list index out of range
