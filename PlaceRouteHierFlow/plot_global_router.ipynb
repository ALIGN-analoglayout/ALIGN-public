# %%
import numpy as np
import json
import platform
import math
import matplotlib.pyplot as plt

# %%
def read_data():
    read_file = "global_router_plt.json"
    data = json.load(open(read_file,'r'))
    global_route = data["Glbaol_Routes"]
    Gcell = data["Gcell"]
    blocks = data["Blocks"]
    node_box = data["Cell box"]
    return global_route,Gcell,blocks,node_box

def plot_global_routing(global_routr,Gcell,blocks,node_box,name):
    
    plt.figure()
    
    plot_box(node_box['LLx'], node_box['LLy'],node_box['URx'],node_box['URy'],'r')
    
    for tile in Gcell:
        plot_dot(tile['x'],tile['y'],'k')
    
    for net in global_routr:
    
        if net['name']!=name:
            continue
    
        for path in net['global_path']:
            plot_line(path['llx'],path['lly'],path['urx'],path['ury'],'r')
        
        for terminal in net['terminals']:
            plot_dot(terminal['x'],terminal['y'],'r')
            
        for stiner_node in net['steiner_node']:
            plot_dot(stiner_node['x'],stiner_node['y'],'g')
    
    plt.show()
    
def plot_box(llx,lly,urx,ury,c):
    plt.plot([llx,urx], [lly,lly], lw=2, color=c)
    plt.plot([urx,urx], [lly,ury], lw=2, color=c)
    plt.plot([urx,llx], [ury,ury], lw=2, color=c)
    plt.plot([llx,llx], [lly,ury], lw=2, color=c)
    
def plot_line(llx,lly,urx,ury,c):
    plt.plot([llx,urx], [lly,ury], lw=2, color=c)
    
def plot_dot(x,y,c):
    plt.plot(x,y, 'o', color=c)

# %%
global_routr,Gcell,blocks,node_box=read_data()

# %%
plot_global_routing(global_routr,Gcell,blocks,node_box,global_routr[0]['name'])
print(global_routr[0])
# Out:
# {'global_path': [{'Physical Layer ll': 2, 'Physical Layer ur': 3, 'llx': 7020, 'lly': 1620, 'urx': 7020, 'ury': 1620}, {'Physical Layer ll': 3, 'Physical Layer ur': 4, 'llx': 7020, 'lly': 1620, 'urx': 7020, 'ury': 1620}, {'Physical Layer ll': 4, 'Physical Layer ur': 4, 'llx': 7020, 'lly': 1620, 'urx': 7020, 'ury': 540}, {'Physical Layer ll': 4, 'Physical Layer ur': 3, 'llx': 7020, 'lly': 540, 'urx': 7020, 'ury': 540}, {'Physical Layer ll': 3, 'Physical Layer ur': 2, 'llx': 7020, 'lly': 540, 'urx': 7020, 'ury': 540}, {'Physical Layer ll': 2, 'Physical Layer ur': 1, 'llx': 7020, 'lly': 540, 'urx': 7020, 'ury': 540}, {'Physical Layer ll': 1, 'Physical Layer ur': 1, 'llx': 7020, 'lly': 540, 'urx': 8100, 'ury': 540}, {'Physical Layer ll': 1, 'Physical Layer ur': 1, 'llx': 8100, 'lly': 540, 'urx': 9180, 'ury': 540}, {'Physical Layer ll': 1, 'Physical Layer ur': 1, 'llx': 9180, 'lly': 540, 'urx': 10260, 'ury': 540}, {'Physical Layer ll': 1, 'Physical Layer ur': 1, 'llx': 10260, 'lly': 540, 'urx': 11340, 'ury': 540}, {'Physical Layer ll': 1, 'Physical Layer ur': 2, 'llx': 11340, 'lly': 540, 'urx': 11340, 'ury': 540}, {'Physical Layer ll': 1, 'Physical Layer ur': 2, 'llx': 10260, 'lly': 540, 'urx': 10260, 'ury': 540}, {'Physical Layer ll': 2, 'Physical Layer ur': 3, 'llx': 10260, 'lly': 540, 'urx': 10260, 'ury': 540}, {'Physical Layer ll': 3, 'Physical Layer ur': 4, 'llx': 10260, 'lly': 540, 'urx': 10260, 'ury': 540}, {'Physical Layer ll': 4, 'Physical Layer ur': 4, 'llx': 10260, 'lly': 540, 'urx': 10260, 'ury': 1620}, {'Physical Layer ll': 4, 'Physical Layer ur': 4, 'llx': 10260, 'lly': 1620, 'urx': 10260, 'ury': 2700}, {'Physical Layer ll': 4, 'Physical Layer ur': 5, 'llx': 10260, 'lly': 2700, 'urx': 10260, 'ury': 2700}, {'Physical Layer ll': 5, 'Physical Layer ur': 5, 'llx': 10260, 'lly': 2700, 'urx': 11340, 'ury': 2700}, {'Physical Layer ll': 5, 'Physical Layer ur': 4, 'llx': 11340, 'lly': 2700, 'urx': 11340, 'ury': 2700}, {'Physical Layer ll': 4, 'Physical Layer ur': 3, 'llx': 11340, 'lly': 2700, 'urx': 11340, 'ury': 2700}, {'Physical Layer ll': 3, 'Physical Layer ur': 2, 'llx': 11340, 'lly': 2700, 'urx': 11340, 'ury': 2700}], 'name': 'net8', 'steiner_node': [], 'terminals': [{'Physical Layer': 2, 'x': 7020, 'y': 1620}, {'Physical Layer': 2, 'x': 11340, 'y': 540}, {'Physical Layer': 2, 'x': 11340, 'y': 2700}]}

# %%
plot_global_routing(global_routr,Gcell,blocks,node_box,global_routr[1]['name'])
print(global_routr[1])
# Out:
# {'global_path': [{'Physical Layer ll': 2, 'Physical Layer ur': 2, 'llx': 7020, 'lly': 1620, 'urx': 7020, 'ury': 1620}], 'name': 'Input2', 'steiner_node': [], 'terminals': [{'Physical Layer': 2, 'x': 7020, 'y': 1620}]}

# %%
plot_global_routing(global_routr,Gcell,blocks,node_box,global_routr[2]['name'])
print(global_routr[2])
# Out:
# {'global_path': [{'Physical Layer ll': 2, 'Physical Layer ur': 3, 'llx': 7020, 'lly': 1620, 'urx': 7020, 'ury': 1620}, {'Physical Layer ll': 3, 'Physical Layer ur': 4, 'llx': 7020, 'lly': 1620, 'urx': 7020, 'ury': 1620}, {'Physical Layer ll': 4, 'Physical Layer ur': 5, 'llx': 7020, 'lly': 1620, 'urx': 7020, 'ury': 1620}, {'Physical Layer ll': 5, 'Physical Layer ur': 5, 'llx': 7020, 'lly': 1620, 'urx': 5940, 'ury': 1620}, {'Physical Layer ll': 5, 'Physical Layer ur': 5, 'llx': 5940, 'lly': 1620, 'urx': 4860, 'ury': 1620}, {'Physical Layer ll': 5, 'Physical Layer ur': 6, 'llx': 4860, 'lly': 1620, 'urx': 4860, 'ury': 1620}, {'Physical Layer ll': 6
ll': 4, 'Physical Layer ur': 3, 'llx': 4860, 'lly': 540, 'urx': 4860, 'ury': 540}, {'Physical Layer ll': 3, 'Physical Layer ur': 2, 'llx': 4860, 'lly': 540, 'urx': 4860, 'ury': 540}, {'Physical Layer ll': 1, 'Physical Layer ur': 2, 'llx': 3780, 'lly': 3780, 'urx': 3780, 'ury': 3780}, {'Physical Layer ll': 2, 'Physical Layer ur': 3, 'llx': 3780, 'lly': 3780, 'urx': 3780, 'ury': 3780}, {'Physical Layer ll': 3, 'Physical Layer ur': 4, 'llx': 3780, 'lly': 3780, 'urx': 3780, 'ury': 3780}, {'Physical Layer ll': 4, 'Physical Layer ur': 4, 'llx': 3780, 'lly': 3780, 'urx': 3780, 'ury': 4698}, {'Physical Layer ll': 4, 'Physical Layer ur': 5, 'llx': 3780, 'lly': 4698, 'urx': 3780, 'ury': 4698}, {'Physical Layer ll': 5, 'Physical Layer ur': 5, 'llx': 3780, 'lly': 4698, 'urx': 2700, 'ury': 4698}, {'Physical ...

# %%
plot_global_routing(global_routr,Gcell,blocks,node_box,global_routr[4]['name'])
print(global_routr[4])
# Out:
# {'global_path': [{'Physical Layer ll': 2, 'Physical Layer ur': 1, 'llx': 11340, 'lly': 2700, 'urx': 11340, 'ury': 2700}, {'Physical Layer ll': 2, 'Physical Layer ur': 2, 'llx': 11340, 'lly': 2700, 'urx': 11340, 'ury': 3780}, {'Physical Layer ll': 2, 'Physical Layer ur': 2, 'llx': 11340, 'lly': 3780, 'urx': 11340, 'ury': 4698}, {'Physical Layer ll': 2, 'Physical Layer ur': 1, 'llx': 11340, 'lly': 4698, 'urx': 11340, 'ury': 4698}, {'Physical Layer ll': 2, 'Physical Layer ur': 2, 'llx': 11340, 'lly': 2700, 'urx': 11340, 'ury': 1620}, {'Physical Layer ll': 2, 'Physical Layer ur': 2, 'llx': 11340, 'lly': 1620, 'urx': 11340, 'ury': 540}], 'name': 'VDD', 'steiner_node': [], 'terminals': [{'Physical Layer': 1, 'x': 11340, 'y': 2700}, {'Physical Layer': 1, 'x': 11340, 'y': 4698}, {'Physical Layer': 2, 'x': 11340, 'y': 540}, {'Physical Layer': 2, 'x': 11340, 'y': 2700}]}

# %%
plot_global_routing(global_routr,Gcell,blocks,node_box,global_routr[5]['name'])
print(global_routr[5])
# Out:
# {'global_path': [{'Physical Layer ll': 2, 'Physical Layer ur': 3, 'llx': 11340, 'lly': 540, 'urx': 11340, 'ury': 540}, {'Physical Layer ll': 3, 'Physical Layer ur': 4, 'llx': 11340, 'lly': 540, 'urx': 11340, 'ury': 540}, {'Physical Layer ll': 4, 'Physical Layer ur': 5, 'llx': 11340, 'lly': 540, 'urx': 11340, 'ury': 540}, {'Physical Layer ll': 5, 'Physical Layer ur': 6, 'llx': 11340, 'lly': 540, 'urx': 11340, 'ury': 540}, {'Physical Layer ll': 6, 'Physical Layer ur': 6, 'llx': 11340, 'lly': 540, 'urx': 11340, 'ury': 1620}, {'Physical Layer ll': 6, 'Physical Layer ur': 5, 'llx': 11340, 'lly': 1620, 'urx': 11340, 'ury': 1620}, {'Physical Layer ll': 5, 'Physical Layer ur': 5, 'llx': 11340, 'lly': 1620, 'urx': 10260, 'ury': 1620}, {'Physical Layer ll': 5, 'Physical Layer ur': 5, 'llx': 10260, 'lly': 1620, 'urx': 9180, 'ury': 1620}, {'Physical Layer ll': 5, 'Physical Layer ur': 5, 'llx': 9180, 'lly': 1620, 'urx': 8100, 'ury': 1620}, {'Physical Layer ll': 5, 'Physical Layer ur': 5, 'llx': 8100, 'lly': 1620, 'urx': 7020, 'ury': 1620}, {'Physical Layer ll': 5, 'Physical Layer ur': 5, 'llx': 7020, 'lly': 1620, 'urx': 5940, 'ury': 1620}, {'Physical Layer ll': 5, 'Physical Layer ur': 5, 'llx': 5940, 'lly': 1620, 'urx': 4860, 'ury': 1620}, {'Physical Layer ll': 5, 'Physical Layer ur': 5, 'llx': 4860, 'lly': 1620, 'urx': 3780, 'ury': 1620}, {'Physical Layer ll': 5, 'Physical Layer ur': 5, 'llx': 3780, 'lly': 1620, 'urx': 2700, 'ury': 1620}, {'Physical Layer ll': 5, 'Physical Layer ur': 5, 'llx': 2700, 'lly': 1620, 'urx': 1620, 'ury': 1620}, {'Physical Layer ll': 5, 'Physical Layer ur': 4, 'llx': 1620, 'lly': 1620, 'urx': 1620, 'ury': 1620}, {'Physical Layer ll': 4, 'Physical Layer ur': 3, 'llx': 1620, 'lly': 1620, 'urx': 1620, 'ury': 1620}, {'Physical Layer ll': 3, 'Physical Layer ur': 2, 'llx': 1620, 'lly': 1620, 'urx': 1620, 'ury': 1620}], 'name': 'VOUT', 'steiner_node': [], 'terminals': [{'Physical Layer': 2, 'x': 1620, 'y': 1620}, {'Physical Layer': 2, 'x': 11340, 'y': 540}]}

# %%
plot_global_routing(global_routr,Gcell,blocks,node_box,global_routr[6]['name'])
print(global_routr[6])
# Out:
# {'global_path': [{'Physical Layer ll': 2, 'Physical Layer ur': 2, 'llx': 1620, 'lly': 1620, 'urx': 1620, 'ury': 1620}], 'name': 'Input1', 'steiner_node': [], 'terminals': [{'Physical Layer': 2, 'x': 1620, 'y': 1620}]}

# %%
plot_global_routing(global_routr,Gcell,blocks,node_box,global_routr[7]['name'])
print(global_routr[7])
# Out:
# {'global_path': [{'Physical Layer ll': 2, 'Physical Layer ur': 2, 'llx': 3780, 'lly': 540, 'urx': 3780, 'ury': 1620}, {'Physical Layer ll': 2, 'Physical Layer ur': 2, 'llx': 3780, 'lly': 1620, 'urx': 3780, 'ury': 2700}], 'name': 'Ids', 'steiner_node': [], 'terminals': [{'Physical Layer': 2, 'x': 3780, 'y': 540}, {'Physical Layer': 2, 'x': 3780, 'y': 2700}]}
